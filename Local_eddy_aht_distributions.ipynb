# %% [markdown]
# ## Import packages

# %%
import xarray as xr
from glob import glob
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
import scipy.stats as sc
import metpy as mtp
import math
from scipy import integrate
import ERA5_functions as era_fncts
import pandas as pd

from matplotlib.pyplot import cm
import datetime as dt

import cartopy.crs as ccrs
from numpy.random import default_rng

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Constants

# %%
a=6371220 #radius of earth in m
L=2.5E6 #Latent heat in atmosphere
L_ice=3.34e5 #Latent heat of fusion
g=9.81 #Acceleration from gravity
conv_pw=1e15 #Conversion from watts to PW
cp=1007

# %% [markdown]
# ### Dims

# %%
lats = np.linspace(90, -90, 361)
lons = np.linspace(0, 359.5, 720)
levels = [1, 2, 3, 5, 7, 10, 20, 30, 50, 70, 100, 125, 150, 175, 200, 225, 250, 300, 350,
            400, 450, 500, 550, 600, 650, 700, 750, 775, 800, 825, 850, 875, 900, 925, 950, 975, 1000]
geometry = 2 * np.pi * np.cos(np.deg2rad(np.asarray(lats))) * a / g

# %% [markdown]
# ### Load instantaneous AHT calcs

# %%
aht_ds = xr.open_dataset('aht_time_series/era5_aht_time_series.nc')

# %% [markdown]
# ### Load local AHT data

# %%
ddir = 'aht_time_series/one_lat/eddy_total_'
local_aht_dict = {}

lats_subset = [35, 40, 45, 50, 55, 60, 65, 70]
for lat in lats_subset:
    eddy_data = []
    eddy_files = sorted(glob(ddir + str(lat) + '*'))
    for file in eddy_files:
        file_data = np.load(file)
        eddy_data.append(file_data)

    eddy_local = np.concatenate(eddy_data)
    local_aht_dict[lat] = eddy_local

# %%
def get_stat(lat, stat, ndjf=True):
    ''' Function to pull summary stats for each longitude from the local_aht_dict
    '''
    
    if ndjf == True:
        local_aht_values = era_fncts.get_ndjf_data(local_aht_dict[lat])
    else:
        local_aht_values = local_aht_dict[lat]
    
    if stat == 'mean':
        summary_stat = np.mean(local_aht_values, axis=0)
        
    elif stat == 'std':
        summary_stat = np.std(local_aht_values, axis=0)
    
    elif stat == 'skew':
        summary_stat = sc.skew(local_aht_values, axis=0)
        
    elif stat == 'kurtosis':
        summary_stat = sc.kurtosis(local_aht_values, axis=0)
        
    elif stat == 'max':
        summary_stat = np.amax(local_aht_values, axis=0)
        
    elif stat == 'min':
        summary_stat = np.amin(local_aht_values, axis=0)
        
    else:
        print('Summary stat not recognized')
        
    return summary_stat

# %%
means = np.zeros((len(lats_subset), 720))
stds = np.zeros((len(lats_subset), 720))
skews = np.zeros((len(lats_subset), 720))
kurtoses = np.zeros((len(lats_subset), 720))
maxs = np.zeros((len(lats_subset), 720))
mins = np.zeros((len(lats_subset), 720))

for idx, lat in enumerate(lats_subset):
    means[idx,:] = get_stat(lat, 'mean')
    stds[idx,:] = get_stat(lat, 'std')
    skews[idx,:] = get_stat(lat, 'skew')
    kurtoses[idx,:] = get_stat(lat, 'kurtosis')
    maxs[idx,:] = get_stat(lat, 'max')
    mins[idx,:] = get_stat(lat, 'min')

# %%
fig, axs = plt.subplots(ncols=1, nrows=4, figsize=(20,30), subplot_kw={'projection': ccrs.PlateCarree(central_longitude=-130)})

axs[0].coastlines()
contf = axs[0].contourf(lons, lats_subset, means / 1e9, levels=np.linspace(0, 7, 30),
                    cmap='bwr', transform=ccrs.PlateCarree())
#get size and extent of axes:
axpos = axs[0].get_position()
pos_x = axpos.x0+axpos.width + 0.01# + 0.25*axpos.width
pos_y = axpos.y0
cax_width = 0.04
cax_height = axpos.height
#create new axes where the colorbar should go.
#it should be next to the original axes and have the same height!
pos_cax = fig.add_axes([pos_x,pos_y,cax_width,cax_height])
plt.colorbar(contf, cax=pos_cax, label='Means')
axs[0].set_title('Mean')

axs[1].coastlines()
contf = axs[1].contourf(lons, lats_subset, stds / 1e9, levels=np.linspace(0, 12, 30),
                    cmap='bwr', transform=ccrs.PlateCarree())
#get size and extent of axes:
axpos = axs[1].get_position()
pos_x = axpos.x0+axpos.width + 0.01# + 0.25*axpos.width
pos_y = axpos.y0
cax_width = 0.04
cax_height = axpos.height
#create new axes where the colorbar should go.
#it should be next to the original axes and have the same height!
pos_cax = fig.add_axes([pos_x,pos_y,cax_width,cax_height])
plt.colorbar(contf, cax=pos_cax, label='Std')
axs[1].set_title('Std')

axs[2].coastlines()
contf = axs[2].contourf(lons, lats_subset, skews, levels=np.linspace(-3, 3, 30),
                    cmap='bwr', transform=ccrs.PlateCarree())
#get size and extent of axes:
axpos = axs[2].get_position()
pos_x = axpos.x0+axpos.width + 0.01# + 0.25*axpos.width
pos_y = axpos.y0
cax_width = 0.04
cax_height = axpos.height
#create new axes where the colorbar should go.
#it should be next to the original axes and have the same height!
pos_cax = fig.add_axes([pos_x,pos_y,cax_width,cax_height])
plt.colorbar(contf, cax=pos_cax, label='Skew')
axs[2].set_title('Skew')

axs[3].coastlines()
contf = axs[3].contourf(lons, lats_subset, kurtoses, levels=np.linspace(-15, 15, 30),
                    cmap='bwr', transform=ccrs.PlateCarree())
#get size and extent of axes:
axpos = axs[3].get_position()
pos_x = axpos.x0+axpos.width + 0.01# + 0.25*axpos.width
pos_y = axpos.y0
cax_width = 0.04
cax_height = axpos.height
#create new axes where the colorbar should go.
#it should be next to the original axes and have the same height!
pos_cax = fig.add_axes([pos_x,pos_y,cax_width,cax_height])
plt.colorbar(contf, cax=pos_cax, label='Kurtoses')
axs[3].set_title('Kurtoses')

#plt.subplots_adjust(wspace=0, hspace=0)

#plt.savefig('figures/3_15_22_meeting/local_eddy_aht_stats')
plt.show()

# %%
plt.plot(lats_subset, np.mean(skews, axis=1))

plt.show()

# %% [markdown]
# ### See if AHT distributions are different in areas of cold air outbreaks versus not

# %% [markdown]
# ### First lets get oriented on a map to decide which regions to choose

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()

ax.set_ylim([0, 90])
ax.set_xlim([-180, 180])

plt.axhline(40, color='r')

plt.axvline(lons[190], color='b')
plt.axvline(lons[240], color='b')

plt.axvline(lons[430]-360, color='g')
plt.axvline(lons[470]-360, color='g')

plt.axvline(lons[520]-360, color='r')
plt.axvline(lons[560]-360, color='r')

plt.show()

# %% [markdown]
# ### Make a function that will grab rolling windows for us and see how much of the AHT is done by the top XX% events

# %%
def get_extremes_rolling_window(which_lat):
    ddir = 'aht_time_series/one_lat/'
    eddy_files = sorted(glob(ddir + 'eddy_total_' + str(which_lat) +'*'))

    eddy_data = []
    for eddy in eddy_files:
        file_data = np.load(eddy)
        eddy_data.append(file_data)

    eddy_local = np.concatenate(eddy_data)
    
    # Lets loop through each longitude with a 20 deg rolling window
    window_size = 40 #In degrees / 2
    rolling_windows = np.zeros((720, len(eddy_local[:,0]) * 40))
    for i in range(720):
        try:
            #print(np.shape(eddy_local[:,i-20:i+20].flatten()))
            rolling_windows[i,:] = eddy_local[:,i-20:i+20].flatten()
        except:
            #print(i)
            pass
        
    extreme_ratio = np.zeros(720)

    for i in range(720):
        rolling_sorted = np.sort(rolling_windows[i,:])
        rolling_window_top_5_perc = rolling_sorted[int(0.95 * len(rolling_sorted)):]

        extreme_ratio[i] = np.sum(rolling_window_top_5_perc) / np.sum(rolling_sorted)
    
    return extreme_ratio

# %%
def get_extremes(which_lat, ndjf=True):

    if ndjf == True:
        eddy_local = era_fncts.get_ndjf_data(local_aht_dict[which_lat])
    else:
        eddy_local = local_aht_dict[which_lat]
    
    extreme_ratio = np.zeros(720)

    for i in range(720):
        data_sorted = np.sort(eddy_local[:,i])
        
        if np.mean(eddy_local[:,i]) > 0:
            data_sorted = np.sort(eddy_local[:,i])
            new_datas = eddy_local[:,i][eddy_local[:,i]>0]
        elif np.mean(eddy_local[:,i]) <= 0:
            data_sorted = np.sort(eddy_local[:,i])[::-1]
            new_datas = eddy_local[:,i][eddy_local[:,i]<0]
            
        data_top_5_perc = data_sorted[int(0.95 * len(data_sorted)):]

        extreme_ratio[i] = np.sum(data_top_5_perc) / np.sum(new_datas)
        
        #if np.mean(data_sorted) < 0:
            #extreme_ratio[i] = 10
        #else:
            #pass
    
    return extreme_ratio

# %% [markdown]
# ### Choose some latitudes and run the function

# %%
test_lats = [35, 40, 45, 50, 55, 60, 65, 70]

extreme_ratios = np.zeros((len(test_lats), 720))
for i in range(len(test_lats)):
    one_lat = test_lats[i]
    #extreme_ratios[i,:] = get_extremes_rolling_window(one_lat)
    extreme_ratios[i,:] = get_extremes(one_lat)

# %%
fig=plt.figure(figsize=(20,30))

ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=-130))
ax.coastlines()

contf = ax.contourf(lons, test_lats, extreme_ratios, levels=np.linspace(0, .5, 30), cmap='bwr',
                    transform=ccrs.PlateCarree(), extend='both')

contf.cmap.set_over('grey')
#contf.cmap.set_under('grey')
contf.changed()

#ax.contour(lons, test_lats, extreme_ratios, levels=[0.55], colors='limegreen', transform=ccrs.PlateCarree())

#get size and extent of axes:
axpos = ax.get_position()
pos_x = axpos.x0+axpos.width + 0.01# + 0.25*axpos.width
pos_y = axpos.y0
cax_width = 0.04
cax_height = axpos.height
#create new axes where the colorbar should go.
#it should be next to the original axes and have the same height!
pos_cax = fig.add_axes([pos_x,pos_y,cax_width,cax_height])


plt.colorbar(contf, cax=pos_cax, label='AHT done by top 5%')

ax.set_title('Positive AHT % Done by top 5% of local events')
#plt.savefig('figures/4_12_22_meeting/eddy_aht_top_5_perc_local_percent_positive_only')
plt.show()
# Out:
# <ipython-input-355-70d005fb0e5d>:9: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("bwr"))
#   contf.cmap.set_over('grey')

# %% [markdown]
# ### Make some dummy data, with specified skewness and kurtosis values to see what role they have in the top 5% of AHT

# %%
#def get_top_5_gaus(mu, sigma, min_range, max_range, gaus_range_param=4):
def get_top_5_gaus(mu, sigma):   
    
    #gaus_range = np.linspace(mu - gaus_range_param * sigma, mu + gaus_range_param * sigma, 1000)
    #gaus_range = np.linspace(-2e10, 2e10, 1000)
    #gaus_range = np.linspace(min_range, max_range, 1000)

    #gaus = np.array(sc.norm.pdf(gaus_range, mu, sigma))
    
    #top_5_perc = np.sum(gaus[int(len(gaus_range) * 0.80):]) / np.sum(gaus)

    #lower_bound = mu + 1.7 * sigma
    #idx = (np.abs(gaus_range - lower_bound)).argmin()
    
    #print(lower_bound)
    #print(gaus_range[idx])
    #bin_width = gaus_range[1]-gaus_range[0]
    #print(gaus[500] * bin_width)
    #top_5_perc = np.sum(gaus[idx:]) / np.sum(gaus)
    
    n_samples = 5000
    
    gaus_samples = np.random.normal(mu, sigma, n_samples)
    
    gaus_samples_sorted = np.sort(gaus_samples)
    
    new_data = gaus_samples[gaus_samples>0]
    
    top_5_perc = np.sum(gaus_samples_sorted[int(len(gaus_samples_sorted) * 0.95):]) / np.sum(new_data)
    
    return top_5_perc#, gaus_range, gaus

# %%
top_5_percs_gaus = np.zeros_like(means)

for i in range(len(lats_subset)):
    for j in range(720):
        
        top_5_percs_gaus[i,j] = get_top_5_gaus(means[i,j], stds[i,j])

# %%
fig=plt.figure(figsize=(20,30))

ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=-130))
ax.coastlines()

space_min = .0
space_max = .5
contf = ax.contourf(lons, test_lats, top_5_percs_gaus, levels=np.linspace(space_min, space_max, 30),
                    cmap='bwr', transform=ccrs.PlateCarree(), extend='both')

contf.cmap.set_over('grey')
#contf.cmap.set_under('grey')
contf.changed()

#ax.contour(lons, test_lats, extreme_ratios, levels=[0.55], colors='limegreen', transform=ccrs.PlateCarree())

#get size and extent of axes:
axpos = ax.get_position()
pos_x = axpos.x0+axpos.width + 0.01# + 0.25*axpos.width
pos_y = axpos.y0
cax_width = 0.04
cax_height = axpos.height
#create new axes where the colorbar should go.
#it should be next to the original axes and have the same height!
pos_cax = fig.add_axes([pos_x,pos_y,cax_width,cax_height])


plt.colorbar(contf, cax=pos_cax, label='AHT done by top 5%')

ax.set_title('AHT % Done by top 5% of gaussian distribution')
#plt.savefig('figures/3_15_22_meeting/eddy_aht_top_5_perc_local_percent_gaussian')
plt.show()
# Out:
# <ipython-input-336-5294fbe3e43a>:11: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("bwr"))
#   contf.cmap.set_over('grey')

# %%
fig=plt.figure(figsize=(20,30))

ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=-130))
ax.coastlines()

space_min = .0
space_max = .2
contf = ax.contourf(lons, test_lats, extreme_ratios - (top_5_percs_gaus), levels=np.linspace(space_min, space_max, 30),
                    cmap='bwr', transform=ccrs.PlateCarree(), extend='both')

contf.cmap.set_over('grey')
#contf.cmap.set_under('grey')
contf.changed()

#ax.contour(lons, test_lats, extreme_ratios, levels=[0.55], colors='limegreen', transform=ccrs.PlateCarree())

#get size and extent of axes:
axpos = ax.get_position()
pos_x = axpos.x0+axpos.width + 0.01# + 0.25*axpos.width
pos_y = axpos.y0
cax_width = 0.04
cax_height = axpos.height
#create new axes where the colorbar should go.
#it should be next to the original axes and have the same height!
pos_cax = fig.add_axes([pos_x,pos_y,cax_width,cax_height])


plt.colorbar(contf, cax=pos_cax, label='AHT done by top 5%')

ax.set_title('AHT % Done by top 5% diference')
#plt.savefig('figures/3_15_22_meeting/eddy_aht_top_5_perc_local_percent')
plt.show()
# Out:
# <ipython-input-343-1c835db871be>:11: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("bwr"))
#   contf.cmap.set_over('grey')
